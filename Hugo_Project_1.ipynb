# %% [markdown]
# <a href="https://colab.research.google.com/github/0HugoHu/HugoHu-Jupyter-Notebook/blob/main/Hugo_Project_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import lib

# %% [markdown]
# ## Read Data

# %%
df = lib.read_data('Glassdoor Gender Pay Gap.csv')

# %% [markdown]
# ## Data Exploration

# %%
lib.describe_data(df)
# Out:
#                Age     PerfEval    Seniority        BasePay         Bonus
# count  1000.000000  1000.000000  1000.000000    1000.000000   1000.000000
# mean     41.393000     3.037000     2.971000   94472.653000   6467.161000
# std      14.294856     1.423959     1.395029   25337.493272   2004.377365
# min      18.000000     1.000000     1.000000   34208.000000   1703.000000
# 25%      29.000000     2.000000     2.000000   76850.250000   4849.500000
# 50%      41.000000     3.000000     3.000000   93327.500000   6507.000000
# 75%      54.250000     4.000000     4.000000  111558.000000   8026.000000
# max      65.000000     5.000000     5.000000  179726.000000  11293.000000

# %% [markdown]
# ## Show Female and Male Salary Distribution

# %%
# NBVAL_SKIP
female_ds = lib.get_female_ds(df)
male_ds = lib.get_male_ds(df)
lib.plot_overall_salary(male_ds, female_ds)

# %% [markdown]
# ## Show Gender Difference

# %%
# NBVAL_SKIP
lib.plot_gender_diff(male_ds, female_ds)
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...
